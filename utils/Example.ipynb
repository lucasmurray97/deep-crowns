# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as T
import torchvision.datasets as D
import torch.nn.functional as F
import numpy as np
import pickle
from matplotlib import pyplot as plt
from torchvision.io import read_image
import fiona
import rasterio
import rasterio.mask
import pathlib
import rioxarray
from utils import MyDataset
from torch.utils.data import DataLoader
from tqdm import tqdm

# %%
dataset = MyDataset("../data", tform=None)

# %%
train_loader = DataLoader(dataset, batch_size=32, shuffle=True, num_workers=8)

# %%
for _, x, y in tqdm(train_loader):
    a = 2 + 2
    
    plt.imshow(x[0][0][0])
    plt.title("Fire")
    plt.colorbar()
    plt.show()
    plt.imshow(x[0][0][1])
    plt.title("Fuels")
    plt.colorbar()
    plt.show()
    plt.imshow(x[0][0][2])
    plt.title("Arqueo")
    plt.colorbar()
    plt.show()
    plt.imshow(x[0][0][3])
    plt.title("Canopy Bulk Density")
    plt.colorbar()
    plt.show()
    plt.imshow(x[0][0][4])
    plt.title("Canopy Base Height")
    plt.colorbar()
    plt.show()
    plt.imshow(x[0][0][5])
    plt.title("Elevation")
    plt.colorbar()
    plt.show()
    plt.imshow(x[0][0][6])
    plt.title("Flora")
    plt.colorbar()
    plt.show()
    plt.imshow(x[0][0][7])
    plt.title("Paleo")
    plt.colorbar()
    plt.show()
    plt.imshow(x[0][0][8])
    plt.title("Urban")
    plt.colorbar()
    plt.show()
    plt.imshow(y[0][0])
    plt.title("Isocrona")
    plt.colorbar()
    plt.show()
# Out:
#   0%|          | 0/2573 [00:00<?, ?it/s]
#   0%|          | 1/2573 [00:06<4:33:19,  6.38s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 7
#       5 plt.title("Fire")
#       6 plt.colorbar()
# ----> 7 plt.show()
#       8 plt.imshow(x[0][0][1])
#       9 plt.title("Fuels")
#
# File ~/Desktop/Trabajo/deep-crowns/venv/lib/python3.11/site-packages/matplotlib/pyplot.py:527, in show(*args, **kwargs)
#     483 """
#     484 Display all open figures.
#     485
#    (...)
#     524 explicitly there.
#     525 """
#     526 _warn_if_gui_out_of_main_thread()
# --> 527 return _get_backend_mod().show(*args, **kwargs)
#
# File ~/Desktop/Trabajo/deep-crowns/venv/lib/python3.11/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~/Desktop/Trabajo/deep-crowns/venv/lib/python3.11/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/Desktop/Trabajo/deep-crowns/venv/lib/python3.11/site-packages/IPython/core/formatters.py:182, in DisplayFormatter.format(self, obj, include, exclude)
#     180 md = None
#     181 try:
# --> 182     data = formatter(obj)
#     183 except:
#     184     # FIXME: log the exception
#     185     raise
#
# File ~/Desktop/Trabajo/deep-crowns/venv/lib/python3.11/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/Desktop/Trabajo/deep-crowns/venv/lib/python3.11/site-packages/IPython/core/formatters.py:226, in catch_format_error(method, self, *args, **kwargs)
#     224 """show traceback on failed format call"""
#     225 try:
# --> 226     r = method(self, *args, **kwargs)
#     227 except NotImplementedError:
#     228     # don't warn on NotImplementedErrors
#     229     return self._check_return(None, args[0])
#
# File ~/Desktop/Trabajo/deep-crowns/venv/lib/python3.11/site-packages/IPython/core/formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     pass
#     342 else:
# --> 343     return printer(obj)
#     344 # Finally look for special method names
#     345 method = get_real_method(obj, self.print_method)
#
# File ~/Desktop/Trabajo/deep-crowns/venv/lib/python3.11/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/Desktop/Trabajo/deep-crowns/venv/lib/python3.11/site-packages/matplotlib/backend_bases.py:2167, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2165 if bbox_inches:
#    2166     if bbox_inches == "tight":
# -> 2167         bbox_inches = self.figure.get_tightbbox(
#    2168             renderer, bbox_extra_artists=bbox_extra_artists)
#    2169         if (isinstance(layout_engine, ConstrainedLayoutEngine) and
#    2170                 pad_inches == "layout"):
#    2171             h_pad = layout_engine.get()["h_pad"]
#
# File ~/Desktop/Trabajo/deep-crowns/venv/lib/python3.11/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~/Desktop/Trabajo/deep-crowns/venv/lib/python3.11/site-packages/matplotlib/figure.py:1774, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    1771     artists = bbox_extra_artists
#    1773 for a in artists:
# -> 1774     bbox = a.get_tightbbox(renderer)
#    1775     if bbox is not None:
#    1776         bb.append(bbox)
#
# File ~/Desktop/Trabajo/deep-crowns/venv/lib/python3.11/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~/Desktop/Trabajo/deep-crowns/venv/lib/python3.11/site-packages/matplotlib/axes/_base.py:4398, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4396         if ba:
#    4397             bb.append(ba)
# -> 4398 self._update_title_position(renderer)
#    4399 axbbox = self.get_window_extent(renderer)
#    4400 bb.append(axbbox)
#
# File ~/Desktop/Trabajo/deep-crowns/venv/lib/python3.11/site-packages/matplotlib/axes/_base.py:2978, in _AxesBase._update_title_position(self, renderer)
#    2976 top = max(top, bb.ymax)
#    2977 if title.get_text():
# -> 2978     ax.yaxis.get_tightbbox(renderer)  # update offsetText
#    2979     if ax.yaxis.offsetText.get_text():
#    2980         bb = ax.yaxis.offsetText.get_tightbbox(renderer)
#
# File ~/Desktop/Trabajo/deep-crowns/venv/lib/python3.11/site-packages/matplotlib/axis.py:1336, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1333     renderer = self.figure._get_renderer()
#    1334 ticks_to_draw = self._update_ticks()
# -> 1336 self._update_label_position(renderer)
#    1338 # go back to just this axis's tick labels
#    1339 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#
# File ~/Desktop/Trabajo/deep-crowns/venv/lib/python3.11/site-packages/matplotlib/axis.py:2614, in YAxis._update_label_position(self, renderer)
#    2612 try:
#    2613     spine = self.axes.spines['left']
# -> 2614     spinebbox = spine.get_window_extent()
#    2615 except KeyError:
#    2616     # use Axes if spine doesn't exist
#    2617     spinebbox = self.axes.bbox
#
# File ~/Desktop/Trabajo/deep-crowns/venv/lib/python3.11/site-packages/matplotlib/spines.py:158, in Spine.get_window_extent(self, renderer)
#     156     return bb
#     157 bboxes = [bb]
# --> 158 drawn_ticks = self.axis._update_ticks()
#     160 major_tick = next(iter({*drawn_ticks} & {*self.axis.majorTicks}), None)
#     161 minor_tick = next(iter({*drawn_ticks} & {*self.axis.minorTicks}), None)
#
# File ~/Desktop/Trabajo/deep-crowns/venv/lib/python3.11/site-packages/matplotlib/axis.py:1276, in Axis._update_ticks(self)
#    1271 """
#    1272 Update ticks (position and labels) using the current data interval of
#    1273 the axes.  Return the list of ticks that will be drawn.
#    1274 """
#    1275 major_locs = self.get_majorticklocs()
# -> 1276 major_labels = self.major.formatter.format_ticks(major_locs)
#    1277 major_ticks = self.get_major_ticks(len(major_locs))
#    1278 for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# File ~/Desktop/Trabajo/deep-crowns/venv/lib/python3.11/site-packages/matplotlib/ticker.py:215, in Formatter.format_ticks(self, values)
#     213 def format_ticks(self, values):
#     214     """Return the tick labels for all the ticks at once."""
# --> 215     self.set_locs(values)
#     216     return [self(value, i) for i, value in enumerate(values)]
#
# File ~/Desktop/Trabajo/deep-crowns/venv/lib/python3.11/site-packages/matplotlib/ticker.py:704, in ScalarFormatter.set_locs(self, locs)
#     702 if len(self.locs) > 0:
#     703     if self._useOffset:
# --> 704         self._compute_offset()
#     705     self._set_order_of_magnitude()
#     706     self._set_format()
#
# File ~/Desktop/Trabajo/deep-crowns/venv/lib/python3.11/site-packages/matplotlib/ticker.py:711, in ScalarFormatter._compute_offset(self)
#     709 locs = self.locs
#     710 # Restrict to visible ticks.
# --> 711 vmin, vmax = sorted(self.axis.get_view_interval())
#     712 locs = np.asarray(locs)
#     713 locs = locs[(vmin <= locs) & (locs <= vmax)]
#
# File ~/Desktop/Trabajo/deep-crowns/venv/lib/python3.11/site-packages/matplotlib/axis.py:2267, in _make_getset_interval.<locals>.getter(self)
#    2265 def getter(self):
#    2266     # docstring inherited.
# -> 2267     return getattr(getattr(self.axes, lim_name), attr_name)
#
# File ~/Desktop/Trabajo/deep-crowns/venv/lib/python3.11/site-packages/matplotlib/axes/_base.py:847, in _AxesBase.viewLim(self)
#     843                 ax._stale_viewlims[name] = False
#     844         self.autoscale_view(**{f"scale{name}": scale
#     845                                for name, scale in need_scale.items()})
# --> 847 @property
#     848 def viewLim(self):
#     849     self._unstale_viewLim()
#     850     return self._viewLim
#
# KeyboardInterrupt:
